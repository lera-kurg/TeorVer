# %%
import scipy.special as sc

# %% [markdown]
# ### Задача 1.38
# > Пятитомное собрание сочинений расположено на полке в случайном порядке.
# Какова вероятность того, что книги стоят слева направо в порядке нумерации томов (от 1 до 5)?
#
#
#
# $$P(A) = \frac{1}{P_5} = \frac{1}{5!}$$

# %%
round(1 / sc.factorial(5), 4)
# Out:
# np.float64(0.0083)

# %% [markdown]
# ### Задача 1.43
# > Наудачу взятый телефонный номер состоит из 5 цифр.
# Какова вероятность того, что в нем все цифры: а) различные;
# б) одинаковые; в) нечетные?
# Известно, что номер телефона не начинается с цифры ноль.
#
# * Рассмотрим событие $A$ - вероятность, что цифры номера будут различные
#
# $$P(A) = \frac{9 \cdot 9 \cdot 8 \cdot 7 \cdot 6}{9 \cdot 10 \cdot 10 \cdot 10 \cdot 10} = \frac{27\,216}{90\,000}$$

# %%
round((9 * 9 * 8 * 7 * 6) / (9*10**4), 4)
# Out:
# 0.3024

# %% [markdown]
# * Рассмотрим событие $Б$ - вероятность, что цифры номера будут одинаковые
#
# $$P(B) = \frac{9}{90\,000}$$

# %%
round(9 / (9*10**4), 5)
# Out:
# 0.0001

# %% [markdown]
# * Рассмотрим событие $В$ - вероятность, что цифры номера будут нечётные
#
#
# $$P(C) = \frac{5 \cdot 5 \cdot 5 \cdot 5 \cdot 5}{90\,000} = \frac{3\,125}{90\,000}$$

# %%
round(5**5 / (9*10**4), 4)
# Out:
# 0.0347

# %% [markdown]
# ### Задача 1.48
# > В старинной игре в кости необходимо было для выигрыша получить при бросании трех игральных костей сумму очков, превосходящую 10.
# Найти вероятности: а) выпадения l l очков; б) выигрыша.
#
# * Рассмотрим событие $A$ - вероятность выпадания 11 очков
#
# $$P(A) = \frac{P_3(1,1,1) + P_3(1,2) + P_3(1,1,1) + P_3(1,1,1) + P_3(2,1) + P_3(1,2)}{6 \cdot 6 \cdot 6} = \frac{6 + 3 + 6 + 6 + 3 + 3}{216} = \frac{1}{8}$$

# %%
round((6+3+6+6+3+3) / 6**3, 4)
# Out:
# 0.125

# %% [markdown]
# * Рассмотрим событие $Б$ - вероятность выигрыша
#
# $$v_{12} = 6 + 6 + 3 + 3 + 6 + 1 = 25$$
# $$v_{13} = 3 + 6 + 6 + 3 + 3 = 21$$
# $$v_{14} = 3 + 6 + 3 + 3 = 15$$
# $$v_{15} = 3 + 6 + 1 = 10$$
# $$v_{16} = 3 + 3 = 6$$
# $$v_{17} = 3$$
# $$v_{18} = 1$$
# $$P(B) = \frac{v_{11} + v_{12} + v_{13} + v_{14} + v_{15} + v_{16} + v_{17} + v_{18}}{216} = \frac{108}{216} = \frac{1}{2}$$

# %%
round((27 + 25 + 21 + 15 + 10 + 6 + 3 + 1) / 6**3, 4)
# Out:
# 0.5
